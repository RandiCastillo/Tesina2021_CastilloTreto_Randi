# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import numpy as np
import os
import shutil
np.random.seed(0)

files = glob.glob('/content/drive/MyDrive/BUS_full/*')

benign_files = [fn for fn in files if 'benign' in fn]
malignant_files = [fn for fn in files if 'malignant' in fn]
len(benign_files), len(malignant_files)
# Out:
# (1775, 931)

# %%
benign_train = np.random.choice(benign_files, size=1598, replace=False)
malignant_train = np.random.choice(malignant_files, size=838, replace=False)
benign_test = list(set(benign_files) - set(benign_train))#
malignant_test = list(set(malignant_files) - set(malignant_train))#

benign_val = np.random.choice(benign_train, size=320, replace=False)
malignant_val = np.random.choice(malignant_train, size=168, replace=False)
benign_train = list(set(benign_train) - set(benign_val))
malignant_train = list(set(malignant_train) - set(malignant_val))

print(len(benign_train),len(malignant_train),len(benign_val),len(malignant_val),len(benign_test),len(malignant_test))
# Out:
# 1278 670 320 168 177 93

# %%
train_dir = '/content/drive/MyDrive/DATASET_BUS_FULL/training_data'
val_dir = '/content/drive/MyDrive/DATASET_BUS_FULL/validation_data'
test_dir = '/content/drive/MyDrive/DATASET_BUS_FULL/test_data'
import shutil
train_files = np.concatenate([benign_train, malignant_train])
validate_files = np.concatenate([benign_val, malignant_val])
test_files = np.concatenate([benign_test, malignant_test])

shutil.rmtree('/content/drive/MyDrive/DATASET_BUS_FULL/training_data',ignore_errors=True)
shutil.rmtree('/content/drive/MyDrive/DATASET_BUS_FULL/validation_data',ignore_errors=True)
shutil.rmtree('/content/drive/MyDrive/DATASET_BUS_FULL/test_data',ignore_errors=True)
##
os.mkdir(train_dir) if not os.path.isdir(train_dir) else None
os.mkdir(val_dir) if not os.path.isdir(val_dir) else None
os.mkdir(test_dir) if not os.path.isdir(test_dir) else None

for fn in train_files:
    shutil.copy(fn, train_dir)

for fn in validate_files:
    shutil.copy(fn, val_dir)
    
for fn in test_files:
    shutil.copy(fn, test_dir)

# %%
files_tr = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/training_data/*')
files_vd = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/validation_data/*')
files_tt = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/test_data/*')
files_tr_benign = [fn for fn in files_tr if 'benign' in fn]
files_tr_malignant = [fn for fn in files_tr if 'malignant' in fn]

files_vd_benign = [fn for fn in files_vd if 'benign' in fn]
files_vd_malignant = [fn for fn in files_vd if 'malignant' in fn]

files_tt_benign = [fn for fn in files_tt if 'benign' in fn]
files_tt_malignant = [fn for fn in files_tt if 'malignant' in fn]
print('Files_tr:',len(files_tr_benign), len(files_tr_malignant))
print('Files_vd:',len(files_vd_benign), len(files_vd_malignant))
print('Files_tt:',len(files_tt_benign), len(files_tt_malignant))

# %% [markdown]
# PREPARING DATASET

# %%
import glob
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
# %matplotlib inline
IMG_DIM = (150,150)

train_files = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[-1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[-1].split('.')[0].strip() for fn in validation_files]

test_files = glob.glob('/content/drive/MyDrive/DATASET_BUS_FULL/test_data/*')
test_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in test_files]
test_imgs = np.array(test_imgs)
test_labels = [fn.split('/')[-1].split('.')[0].strip() for fn in test_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape,'\tTest dataset shape:', test_imgs.shape)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
test_imgs_scaled =test_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255
test_imgs_scaled /= 255

print(train_imgs[0].shape)
array_to_img(train_imgs[0])

# %%
print(train_imgs[6].shape)
array_to_img(train_imgs[6])

# %%
print(test_imgs[25].shape)
array_to_img(test_imgs[25])

# %%
batch_size = 30
num_classes = 2
epochs = 30
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)
test_labels_enc = le.transform(test_labels)

print(train_labels[25:30], train_labels_enc[25:30], test_labels_enc[25:30])

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=20,brightness_range=[.5,1.5],
                                   width_shift_range=0, height_shift_range=0, shear_range=0, 
                                   horizontal_flip=True, fill_mode='constant')

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 6
bening_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
bening = [next(bening_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in bening])
l = [ax[i].imshow(bening[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['benign', 'benign', 'benign', 'benign', 'benign']

# %%
img_id = 1500
malignant_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
malignant = [next(malignant_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in malignant])
l = [ax[i].imshow(malignant[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)
test_generator = test_datagen.flow(test_imgs, test_labels_enc, batch_size=20)
input_shape = (150, 150, 3)
TRAIN_STEPS_PER_EPOCH = np.ceil((len(train_imgs)/30)-1)
# to ensure that there are enough images for training bahch
VAL_STEPS_PER_EPOCH = np.ceil((len(validation_imgs)/20)-1)
print(TRAIN_STEPS_PER_EPOCH,VAL_STEPS_PER_EPOCH)
# Out:
# 64.0 24.0

# %% [markdown]
# ---------------------------------------------

# %%
import keras
from keras.models import Sequential
from keras import optimizers
from keras.preprocessing import image
##
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.models import Model
import pandas as pd
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer, GlobalAveragePooling2D, Input

#base_model = ResNet50(
#    weights="imagenet",  # Load weights pre-trained on ImageNet.
#    input_shape=input_shape,
#    include_top=False,
#)  # Do not include the ImageNet classifier at the top.
model = Sequential()
# 1st layer as the lumpsum weights from resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# NOTE that this layer will be set below as NOT TRAINABLE, i.e., use it as is
model.add(ResNet50(include_top = False, pooling = 'avg', weights = "imagenet"))

# 2nd layer as Dense for 2-class classification, i.e., dog or cat using SoftMax activation
model.add(Dense(1, activation = 'sigmoid'))

# Say not to train first layer (ResNet) model as it is already trained
model.layers[0].trainable = False
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 23,589,761
# Trainable params: 2,049
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
import tensorflow_datasets as tfds
import pathlib
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import time
from keras.models import load_model
from keras.optimizers import SGD
sgd = optimizers.SGD(lr = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(loss='binary_crossentropy',
                  optimizer= sgd,
                  metrics=['accuracy'])
tic=time.time()
# training
filepath='/content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5'
mc = ModelCheckpoint(filepath, monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = [mc]
history = model.fit(
    train_generator, steps_per_epoch=TRAIN_STEPS_PER_EPOCH,  epochs=50,
    validation_data = val_generator, validation_steps=VAL_STEPS_PER_EPOCH, verbose=1,callbacks=[es])
# training
print('Tiempo de procesamiento (secs): ', time.time()-tic)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 15s 204ms/step - loss: 0.6999 - accuracy: 0.6039 - val_loss: 0.6915 - val_accuracy: 0.6500
#
# Epoch 00001: val_accuracy improved from -inf to 0.65000, saving model to /content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-01-0.65.hdf5
# Epoch 2/50
# 64/64 [==============================] - 12s 192ms/step - loss: 0.7141 - accuracy: 0.5992 - val_loss: 0.7572 - val_accuracy: 0.6542
#
# Epoch 00002: val_accuracy improved from 0.65000 to 0.65417, saving model to /content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-02-0.65.hdf5
# Epoch 3/50
# 64/64 [==============================] - 12s 191ms/step - loss: 0.6714 - accuracy: 0.6392 - val_loss: 0.6497 - val_accuracy: 0.6438
#
# Epoch 00003: val_accuracy did not improve from 0.65417
# Epoch 4/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6833 - accuracy: 0.6301 - val_loss: 0.6029 - val_accuracy: 0.6625
#
# Epoch 00004: val_accuracy improved from 0.65417 to 0.66250, saving model to /content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-04-0.66.hdf5
# Epoch 5/50
# 64/64 [==============================] - 12s 191ms/step - loss: 0.6618 - accuracy: 0.6499 - val_loss: 0.6120 - val_accuracy: 0.6542
#
# Epoch 00005: val_accuracy did not improve from 0.66250
# Epoch 6/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.6677 - accuracy: 0.6193 - val_loss: 0.6164 - val_accuracy: 0.7188
#
# Epoch 00006: val_accuracy improved from 0.66250 to 0.71875, saving model to /content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-06-0.72.hdf5
# Epoch 7/50
# 64/64 [==============================] - 12s 192ms/step - loss: 0.7099 - accuracy: 0.6241 - val_loss: 0.8256 - val_accuracy: 0.6583
#
# Epoch 00007: val_accuracy did not improve from 0.71875
# Epoch 8/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.7286 - accuracy: 0.6141 - val_loss: 0.6717 - val_accuracy: 0.5688
#
# Epoch 00008: val_accuracy did not improve from 0.71875
# Epoch 9/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.6783 - accuracy: 0.6191 - val_loss: 0.5970 - val_accuracy: 0.6562
#
# Epoch 00009: val_accuracy did not improve from 0.71875
# Epoch 10/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6548 - accuracy: 0.6389 - val_loss: 0.6368 - val_accuracy: 0.6583
#
# Epoch 00010: val_accuracy did not improve from 0.71875
# Epoch 11/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.7310 - accuracy: 0.5945 - val_loss: 0.6569 - val_accuracy: 0.5958
#
# Epoch 00011: val_accuracy did not improve from 0.71875
# Epoch 12/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6804 - accuracy: 0.6101 - val_loss: 0.6006 - val_accuracy: 0.7125
#
# Epoch 00012: val_accuracy did not improve from 0.71875
# Epoch 13/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6500 - accuracy: 0.6393 - val_loss: 0.6055 - val_accuracy: 0.7104
#
# Epoch 00013: val_accuracy did not improve from 0.71875
# Epoch 14/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.6665 - accuracy: 0.6390 - val_loss: 0.6675 - val_accuracy: 0.6562
#
# Epoch 00014: val_accuracy did not improve from 0.71875
# Epoch 15/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6647 - accuracy: 0.6239 - val_loss: 0.6414 - val_accuracy: 0.6333
#
# Epoch 00015: val_accuracy did not improve from 0.71875
# Epoch 16/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6615 - accuracy: 0.6245 - val_loss: 0.6091 - val_accuracy: 0.7083
#
# Epoch 00016: val_accuracy did not improve from 0.71875
# Epoch 17/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6541 - accuracy: 0.6320 - val_loss: 0.6801 - val_accuracy: 0.5500
#
# Epoch 00017: val_accuracy did not improve from 0.71875
# Epoch 18/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6739 - accuracy: 0.6129 - val_loss: 0.5961 - val_accuracy: 0.7104
#
# Epoch 00018: val_accuracy did not improve from 0.71875
# Epoch 19/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6474 - accuracy: 0.6410 - val_loss: 0.6304 - val_accuracy: 0.6500
#
# Epoch 00019: val_accuracy did not improve from 0.71875
# Epoch 20/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6701 - accuracy: 0.6216 - val_loss: 0.5921 - val_accuracy: 0.6604
#
# Epoch 00020: val_accuracy did not improve from 0.71875
# Epoch 21/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6520 - accuracy: 0.6242 - val_loss: 0.5939 - val_accuracy: 0.7146
#
# Epoch 00021: val_accuracy did not improve from 0.71875
# Epoch 22/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6328 - accuracy: 0.6628 - val_loss: 0.6314 - val_accuracy: 0.6604
#
# Epoch 00022: val_accuracy did not improve from 0.71875
# Epoch 23/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.6712 - accuracy: 0.6360 - val_loss: 0.6130 - val_accuracy: 0.6562
#
# Epoch 00023: val_accuracy did not improve from 0.71875
# Epoch 24/50
# 64/64 [==============================] - 12s 184ms/step - loss: 0.6780 - accuracy: 0.6262 - val_loss: 0.6389 - val_accuracy: 0.6521
#
# Epoch 00024: val_accuracy did not improve from 0.71875
# Epoch 25/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6539 - accuracy: 0.6305 - val_loss: 0.6195 - val_accuracy: 0.6583
#
# Epoch 00025: val_accuracy did not improve from 0.71875
# Epoch 26/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6399 - accuracy: 0.6576 - val_loss: 0.6030 - val_accuracy: 0.6583
#
# Epoch 00026: val_accuracy did not improve from 0.71875
# Epoch 27/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6725 - accuracy: 0.6331 - val_loss: 0.6165 - val_accuracy: 0.6521
#
# Epoch 00027: val_accuracy did not improve from 0.71875
# Epoch 28/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6676 - accuracy: 0.6373 - val_loss: 0.6082 - val_accuracy: 0.6562
#
# Epoch 00028: val_accuracy did not improve from 0.71875
# Epoch 29/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.7199 - accuracy: 0.5875 - val_loss: 0.6565 - val_accuracy: 0.5917
#
# Epoch 00029: val_accuracy did not improve from 0.71875
# Epoch 30/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6357 - accuracy: 0.6549 - val_loss: 0.6445 - val_accuracy: 0.6187
#
# Epoch 00030: val_accuracy did not improve from 0.71875
# Epoch 31/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.7009 - accuracy: 0.5930 - val_loss: 0.5890 - val_accuracy: 0.7083
#
# Epoch 00031: val_accuracy did not improve from 0.71875
# Epoch 32/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6770 - accuracy: 0.6184 - val_loss: 0.5983 - val_accuracy: 0.6542
#
# Epoch 00032: val_accuracy did not improve from 0.71875
# Epoch 33/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6988 - accuracy: 0.5918 - val_loss: 0.5948 - val_accuracy: 0.7146
#
# Epoch 00033: val_accuracy did not improve from 0.71875
# Epoch 34/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6699 - accuracy: 0.6289 - val_loss: 0.5976 - val_accuracy: 0.6604
#
# Epoch 00034: val_accuracy did not improve from 0.71875
# Epoch 35/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6762 - accuracy: 0.6066 - val_loss: 0.7869 - val_accuracy: 0.6562
#
# Epoch 00035: val_accuracy did not improve from 0.71875
# Epoch 36/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6643 - accuracy: 0.6443 - val_loss: 0.5863 - val_accuracy: 0.6687
#
# Epoch 00036: val_accuracy did not improve from 0.71875
# Epoch 37/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6648 - accuracy: 0.6284 - val_loss: 0.6182 - val_accuracy: 0.6583
#
# Epoch 00037: val_accuracy did not improve from 0.71875
# Epoch 38/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6608 - accuracy: 0.6237 - val_loss: 0.6587 - val_accuracy: 0.6562
#
# Epoch 00038: val_accuracy did not improve from 0.71875
# Epoch 39/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6796 - accuracy: 0.6301 - val_loss: 0.6940 - val_accuracy: 0.6521
#
# Epoch 00039: val_accuracy did not improve from 0.71875
# Epoch 40/50
# 64/64 [==============================] - 12s 189ms/step - loss: 0.6412 - accuracy: 0.6399 - val_loss: 0.6195 - val_accuracy: 0.6729
#
# Epoch 00040: val_accuracy did not improve from 0.71875
# Epoch 41/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6562 - accuracy: 0.6478 - val_loss: 0.6018 - val_accuracy: 0.6542
#
# Epoch 00041: val_accuracy did not improve from 0.71875
# Epoch 42/50
# 64/64 [==============================] - 12s 188ms/step - loss: 0.6315 - accuracy: 0.6421 - val_loss: 0.7085 - val_accuracy: 0.5083
#
# Epoch 00042: val_accuracy did not improve from 0.71875
# Epoch 43/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6554 - accuracy: 0.6318 - val_loss: 0.5876 - val_accuracy: 0.6646
#
# Epoch 00043: val_accuracy did not improve from 0.71875
# Epoch 44/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6509 - accuracy: 0.6746 - val_loss: 0.6303 - val_accuracy: 0.6542
#
# Epoch 00044: val_accuracy did not improve from 0.71875
# Epoch 45/50
# 64/64 [==============================] - 12s 185ms/step - loss: 0.6703 - accuracy: 0.6134 - val_loss: 0.6570 - val_accuracy: 0.5854
#
# Epoch 00045: val_accuracy did not improve from 0.71875
# Epoch 46/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6825 - accuracy: 0.6171 - val_loss: 0.6140 - val_accuracy: 0.6562
#
# Epoch 00046: val_accuracy did not improve from 0.71875
# Epoch 47/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6577 - accuracy: 0.6389 - val_loss: 0.5939 - val_accuracy: 0.7083
#
# Epoch 00047: val_accuracy did not improve from 0.71875
# Epoch 48/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6650 - accuracy: 0.6361 - val_loss: 0.6875 - val_accuracy: 0.5479
#
# Epoch 00048: val_accuracy did not improve from 0.71875
# Epoch 49/50
# 64/64 [==============================] - 12s 186ms/step - loss: 0.6448 - accuracy: 0.6232 - val_loss: 0.6364 - val_accuracy: 0.6396
#
# Epoch 00049: val_accuracy did not improve from 0.71875
# Epoch 50/50
# 64/64 [==============================] - 12s 187ms/step - loss: 0.6767 - accuracy: 0.6100 - val_loss: 0.7534 - val_accuracy: 0.4646
#
# Epoch 00050: val_accuracy did not improve from 0.71875
# Tiempo de procesamiento (secs):  606.4843153953552

# %%
plt.figure(1)

# summarize history for accuracy

plt.subplot(211)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

# summarize history for loss

plt.subplot(212)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')

plt.tight_layout()

plt.show()

# %%
model.load_weights("/content/drive/MyDrive/MODELOS/resnet50_full/weights-improvement-06-0.72.hdf5")
scores = model.evaluate(
    test_imgs_scaled,
    test_labels_enc,
    batch_size=64,

    verbose=0,
    workers=1,
    use_multiprocessing=False,
    return_dict=False,
)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 63.70%
